# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#DRAWING A CYLINDER
# Parameters for the cylinder
radius = 5  # Cylinder radius
height = 10  # Cylinder height
num_points = 200  # Number of points around the cylinder's circumference

# %%
# Create a meshgrid for the cylinder's angle (theta) and height (z)
theta = np.linspace(0, 2*np.pi, num_points)  # Angle around the cylinder
z = np.linspace(0, height, num_points)      # Height of the cylinder
theta, Z = np.meshgrid(theta, z)

# %%
# Parametric equations for a cylinder
X = radius * np.cos(theta)
Y = radius * np.sin(theta)

# %%
# Plot the cylinder
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, color='red', edgecolor='BLUE')
# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Show the plot
plt.show()

# %%
import math

def volume_cylinder(radius, height):
    return math.pi * radius**2 * height

radius_cylinder = 5
height_cylinder = 10

# Calculating volumes
print("Volume of Cylinder:", volume_cylinder(radius_cylinder, height_cylinder))
# Out:
# Volume of Cylinder: 785.3981633974483

# %%
#DRAWING A CONE
# Parameters for the cone
radius = 3  # Cone radius at the base
height = 6  # Height of the cone
num_points = 200  # Number of points around the cone

# %%
# Create a meshgrid for the cone's angle (theta) and height (z)
theta = np.linspace(0, 2*np.pi, num_points)
z = np.linspace(0, height, num_points)
theta, Z = np.meshgrid(theta, z)

# %%
# Parametric equations for the cone
X = radius * (1 - Z/height) * np.cos(theta)
Y = radius * (1 - Z/height) * np.sin(theta)

# %%
# Plot the cone in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, color='RED', edgecolor='BLUE')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Display the plot
plt.show()

# %%
import math
#volume of cone
def volume_cone(radius, height):
    return (1/3) * math.pi * radius**2 * height

radius_cone = 3
height_cone = 6

print("Volume of Cone:", volume_cone(radius_cone, height_cone), "cubic units")
# Out:
# Volume of Cone: 56.548667764616276 cubic units

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 4
num_points = 200

# %%
# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)

# %%
# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# %%
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface of the sphere
ax.plot_surface(x, y, z, color='RED', edgecolor='BLUE', linewidth=0.5)

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Display the plot
plt.show()

# %%
def volume_sphere(radius):
    return (4/3) * math.pi * radius**3

radius_sphere = 4

# Calculating volumes
print("Volume of Sphere:", volume_sphere(radius_sphere), 'cubic units')
# Out:
# Volume of Sphere: 268.082573106329 cubic units

# %%
#DRAWING CUBE
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
# Define the vertices of the cube
vertices = np.array([
    [0, 0, 0],  # Corner 1 (0, 0, 0)
    [1, 0, 0],  # Corner 2 (1, 0, 0)
    [1, 1, 0],  # Corner 3 (1, 1, 0)
    [0, 1, 0],  # Corner 4 (0, 1, 0)
    [0, 0, 1],  # Corner 5 (0, 0, 1)
    [1, 0, 1],  # Corner 6 (1, 0, 1)
    [1, 1, 1],  # Corner 7 (1, 1, 1)
    [0, 1, 1]   # Corner 8 (0, 1, 1)
])

# Define the 6 faces of the cube using vertex indices
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right
    [vertices[4], vertices[7], vertices[3], vertices[0]]   # Left
]

# %%
# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(faces, facecolors='RED', linewidths=1, edgecolors='BLUE', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.set_zlim([0, 1])

# Show the plot
plt.show()

# %%
# Define the initial corner and edge length
initial_corner = np.array([3, 5, 4])
edge_length = 5

# Calculate the vertices of the cube
vertices = [
    initial_corner, #(3, 5, 4)
    initial_corner + [edge_length, 0, 0], #(8, 5, 4)
    initial_corner + [edge_length, edge_length, 0], #(8, 10, 4),
    initial_corner + [0, edge_length, 0], #(3, 10, 4),
    initial_corner + [0, 0, edge_length], # (3, 5, 9),
    initial_corner + [edge_length, 0, edge_length], #(8, 5, 9),
    initial_corner + [edge_length, edge_length, edge_length], #(8, 10, 9),
    initial_corner + [0, edge_length, edge_length], #(3, 10, 9),
]

# Define the faces of the cube using vertex indices
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right
    [vertices[4], vertices[7], vertices[3], vertices[0]]   # Left
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(faces, facecolors='RED', linewidths=1, edgecolors='BLUE', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes to encompass the cube
ax.set_xlim([initial_corner[0], initial_corner[0] + edge_length])
ax.set_ylim([initial_corner[1], initial_corner[1] + edge_length])
ax.set_zlim([initial_corner[2], initial_corner[2] + edge_length])

# Show the plot
plt.show()

# %%
def distance_3d(point1, point2):
  """Calculates the Euclidean distance between two points in 3D space.

  Args:
    point1: A tuple or list representing the coordinates of the first point (x1, y1, z1).
    point2: A tuple or list representing the coordinates of the second point (x2, y2, z2).

  Returns:
    The Euclidean distance between the two points.
  """
  # Convert the points to NumPy arrays for efficient calculations
  point1 = np.array(point1)
  point2 = np.array(point2)

  # Calculate the distance using the formula: sqrt((x2 - x1)^2 + (y2 - y1)^2 + (z2 - z1)^2)
  distance = np.sqrt(np.sum((point2 - point1)**2))

  return distance

# Example usage:
point_a = (1, 2, 3)
point_b = (4, 5, 6)

distance = distance_3d(point_a, point_b)
print(f"The distance between {point_a} and {point_b} is: {distance}")
# Out:
# The distance between (1, 2, 3) and (4, 5, 6) is: 5.196152422706632

# %%
def volume_cube(side_cube):
    return side_cube**3
side_cube = 5

# Calculating volumes
print("Volume of Cube:", volume_cube(side_cube), 'cubic units')
# Out:
# Volume of Cube: 125 cubic units

# %%
#DRAWING PYRAMID
# Parameters for the pyramid
base_size = 16  # Side length of the square base
height = 9     # Height of the pyramid

# Define the vertices of the pyramid
vertices = np.array([
    [-base_size/2, -base_size/2, 0],  # Base corner 1
    [ base_size/2, -base_size/2, 0],  # Base corner 2
    [ base_size/2,  base_size/2, 0],  # Base corner 3
    [-base_size/2,  base_size/2, 0],  # Base corner 4
    [ 0, 0, height]                   # Apex
])

# Define the faces of the pyramid (4 triangles + 1 square base)
faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

# %%
# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the pyramid
ax.add_collection3d(Poly3DCollection(faces, facecolors='RED', linewidths=1, edgecolors='BLUE', alpha=.5))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for the axes
ax.set_xlim([-base_size, base_size])
ax.set_ylim([-base_size, base_size])
ax.set_zlim([0, height])

# Display the plot
plt.show()

# %%
def volume_pyramid(base_area_pyramid, height_pyramid):
      return (1/3) * base_area_pyramid * height_pyramid

base_area_pyramid = 16  # Square base of side 4
height_pyramid = 9
print("Volume of Pyramid:", volume_pyramid(base_area_pyramid, height_pyramid))
# Out:
# Volume of Pyramid: 48.0

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 2  # Length of the prism
width = 3   # Width of the prism
height = 4  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [0, 0, 0],  # Vertex 0
    [length, 0, 0],  # Vertex 1
    [length, width, 0],  # Vertex 2
    [0, width, 0],  # Vertex 3
    [0, 0, height],  # Vertex 4
    [length, 0, height],  # Vertex 5
    [length, width, height],  # Vertex 6
    [0, width, height],  # Vertex 7
])

# Define the 6 faces of the rectangular prism
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom face
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top face
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right face
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back face
    [vertices[3], vertices[0], vertices[4], vertices[7]],  # Left face
]

# %%
# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the rectangular prism
ax.add_collection3d(Poly3DCollection(faces, facecolors='RED', linewidths=1, edgecolors='BLUE', alpha=.5))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for the axes
ax.set_xlim([0, length])
ax.set_ylim([0, width])
ax.set_zlim([0, height])

# Display the plot
plt.show()

# %%
def volume_prism(lenght_prism, width_prism, height_prism):
      return lenght_prism * width_prism * height_prism

lenght_prism = 2
width_prism = 3
height_prism = 4

print("Volume of Prism:", volume_prism(lenght_prism, width_prism, height_prism))
# Out:
# Volume of Prism: 24

# %%
#DRAWING VOXELS
# Parameters for the voxel grid
grid_size = 5  # Size of the grid (5x5x5 grid of voxels)
voxel_size = 1  # Size of each voxel (cube)

# %%
# Create a figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Loop over the 3D grid and draw cubes (voxels)
for x in range(grid_size):
    for y in range(grid_size):
        for z in range(grid_size):
            # Voxel's corner coordinates
            x_pos = x * voxel_size
            y_pos = y * voxel_size
            z_pos = z * voxel_size

            # Create a voxel as a 3D cube using plot_surface
            # Each voxel is represented by a box defined by its corners
            ax.bar3d(x_pos, y_pos, z_pos, voxel_size, voxel_size, voxel_size, color='YELLOW', linewidths=0.5)

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the viewing angle
ax.view_init(20, 75)

# Show the plot
plt.show()

# %%
#Union of Sphere and Cube
def create_sphere(radius=0.8):
       theta = np.linspace(0, 2 * np.pi, 100)
       phi = np.linspace(0, np.pi, 100)
       theta, phi = np.meshgrid(theta, phi)
       x = radius * np.sin(phi) * np.cos(theta)
       y = radius * np.sin(phi) * np.sin(theta)
       z = radius * np.cos(phi)
       return x, y, z

def create_cube(size=1):
       vertices = np.array([
           [0, 0, 0], [size, 0, 0], [size, size, 0], [0, size, 0],
           [0, 0, size], [size, 0, size], [size, size, size], [0, size, size]
       ])
       faces = [
           [vertices[0], vertices[1], vertices[2], vertices[3]],
           [vertices[4], vertices[5], vertices[6], vertices[7]],
           [vertices[0], vertices[1], vertices[5], vertices[4]],
           [vertices[2], vertices[3], vertices[7], vertices[6]],
           [vertices[1], vertices[2], vertices[6], vertices[5]],
           [vertices[4], vertices[7], vertices[3], vertices[0]]
       ]
       return vertices, faces

# %%
sphere_x, sphere_y, sphere_z = create_sphere()
cube_vertices, cube_faces = create_cube()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the sphere
ax.plot_surface(sphere_x, sphere_y, sphere_z, color='yellow', edgecolor='yellow', linewidth=0.5, alpha=0.5)

# Plot the cube
ax.add_collection3d(Poly3DCollection(cube_faces, facecolors='yellow', linewidths=1, edgecolors='yellow', alpha=0.5))

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
# Create a 3D plot
fig = plt.figure()

# Add a 3D axis
ax = fig.add_subplot(111, projection='3d')

# Create a sine wave
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)

# Plot the sine wave in 3D
ax.plot(x, y, z, color='red')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()

# %%
def distance_3d(point1, point2):
    point1 = np.array(point1)
    point2 = np.array(point2)
    
    distance = np.sqrt(np.sum((point2 - point1)**2))
    
    return distance

# Define the points X, Y, and Z

point_x = (2, 3, 6)
point_y = (7, 8, 9)
point_z = (2, 9, 4)

# Calculate the distances
distance_xy = distance_3d(point_x, point_y)
distance_xz = distance_3d(point_x, point_z)

print(f"A. The distance between X and Y is: {distance_xy}")
print(f"B. The distance between X and Z is: {distance_xz}")
# Out:
# A. The distance between X and Y is: 7.681145747868608
# B. The distance between X and Z is: 6.324555320336759

# %%
# Cylinder whose radius = 13.3, height = 17 and number of points/resolution = 450 (yellow)

# Parameters for the cylinder
radius = 13.3  # Cylinder radius
height = 17  # Cylinder height
num_points = 450  # Number of points around the cylinder's circumference

# Create a meshgrid for the cylinder's angle (theta) and height (z)
theta = np.linspace(0, 2*np.pi, num_points)  # Angle around the cylinder
z = np.linspace(0, height, num_points)      # Height of the cylinder
theta, Z = np.meshgrid(theta, z)

# Parametric equations for a cylinder
X = radius * np.cos(theta)
Y = radius * np.sin(theta)

# Plot the cylinder
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, color='yellow', edgecolor='red')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()

# %%
#Cone whose radius = 13.3, height = 17 and number of points/resolution = 450 (cyan)

# Parameters for the cone
radius = 13.3  # Cone radius at the base
height = 17  # Height of the cone
num_points = 450  # Number of points around the cone

# Create a meshgrid for the cone's angle (theta) and height (z)
theta = np.linspace(0, 2*np.pi, num_points)
z = np.linspace(0, height, num_points)
theta, Z = np.meshgrid(theta, z)

# Parametric equations for the cone
X = radius * (1 - Z/height) * np.cos(theta)
Y = radius * (1 - Z/height) * np.sin(theta)

# Plot the cone in 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, color='cyan', edgecolor='red')

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Display the plot
plt.show()

# %%
#Sphere whose radius = 13.3 and number of points/resolution = 450 (magenta)

# Define the radius of the sphere
radius = 13.3
num_points = 450

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)

# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface of the sphere
ax.plot_surface(x, y, z, color='magenta', edgecolor='red', linewidth=0.5)

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Display the plot
plt.show()

# %%
# Cube whose initial coordinate located at (4, 8, 9) and the edge is 12. (blue)

# Define the initial corner and edge length
initial_corner = np.array([4, 8, 9])
edge_length = 12

# Calculate the vertices of the cube
vertices = [
    initial_corner, #(4, 8, 9)
    initial_corner + [edge_length, 0, 0], #(16, 8, 9)
    initial_corner + [edge_length, edge_length, 0], #(16, 20, 9),
    initial_corner + [0, edge_length, 0], #(4, 20, 9),
    initial_corner + [0, 0, edge_length], # (4, 8, 21),
    initial_corner + [edge_length, 0, edge_length], #(16, 8, 21),
    initial_corner + [edge_length, edge_length, edge_length], #(16, 20, 21),
    initial_corner + [0, edge_length, edge_length], #(4, 20, 21),
]

# Define the faces of the cube using vertex indices
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right
    [vertices[4], vertices[7], vertices[3], vertices[0]]   # Left
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Add the faces to the plot
ax.add_collection3d(Poly3DCollection(faces, facecolors='blue', linewidths=1, edgecolors='red', alpha=.30))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set limits for the axes to encompass the cube
ax.set_xlim([initial_corner[0], initial_corner[0] + edge_length])
ax.set_ylim([initial_corner[1], initial_corner[1] + edge_length])
ax.set_zlim([initial_corner[2], initial_corner[2] + edge_length])

# Show the plot
plt.show()

# %%
# Pyramid whose base is rectangle (L = 21 and W = 16) and height is 23 units. (green)

# Parameters for the pyramid
base_width = 21  # Width of the base
base_length = 16  # Length of the base
height = 23  # Height of the pyramid

# Define the vertices of the pyramid
vertices = np.array([
    [-base_length/2, -base_width/2, 0],  # Base corner 1
    [ base_length/2, -base_width/2, 0],  # Base corner 2
    [ base_length/2,  base_width/2, 0],  # Base corner 3
    [-base_length/2,  base_width/2, 0],  # Base corner 4
    [ 0, 0, height]                   # Apex
])

# Define the faces of the pyramid (4 triangles + 1 square base)
faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the pyramid
ax.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='red', alpha=.5))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for the axes
ax.set_xlim([-base_length, base_length])
ax.set_ylim([-base_width, base_width])
ax.set_zlim([0, height])

# Display the plot
plt.show()

# %%
# Prism whose base is rectangle (L = 21 and W = 16) and height is 23 units. (orange)

# Parameters for the rectangular prism
length = 21  # Length of the prism
width = 16  # Width of the prism
height = 23  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [0, 0, 0],  # Vertex 0
    [length, 0, 0],  # Vertex 1
    [length, width, 0],  # Vertex 2
    [0, width, 0],  # Vertex 3
    [0, 0, height],  # Vertex 4
    [length, 0, height],  # Vertex 5
    [length, width, height],  # Vertex 6
    [0, width, height],  # Vertex 7
])

# Define the 6 faces of the rectangular prism
faces = [
    [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom face
    [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top face
    [vertices[0], vertices[1], vertices[5], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[6], vertices[5]],  # Right face
    [vertices[2], vertices[3], vertices[7], vertices[6]],  # Back face
    [vertices[3], vertices[0], vertices[4], vertices[7]],  # Left face
]

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the rectangular prism
ax.add_collection3d(Poly3DCollection(faces, facecolors='orange', linewidths=1, edgecolors='red', alpha=.5))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for the axes
ax.set_xlim([0, length])
ax.set_ylim([0, width])
ax.set_zlim([0, height])

# Display the plot
plt.show()
