# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the quadratic Bezier curve function
def quadratic_bezier(t, p0, p1, p2):
    x = (1 - t) ** 2 * p0[0] + 2 * (1 - t) * t * p1[0] + t ** 2 * p2[0]
    y = (1 - t) ** 2 * p0[1] + 2 * (1 - t) * t * p1[1] + t ** 2 * p2[1]
    return x, y

# Set up the plot
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.set_xlim(0, 600)
ax.set_ylim(0, 600)
ax.set_facecolor((240/255, 240/255, 240/255))

# Draw the cross using lines and quadratic Bezier curves
# Top part
ax.plot([250, 250], [280, 180], 'k-', linewidth=4)
ax.plot([350, 350], [180, 280], 'k-', linewidth=4)
ax.plot([290, 310], [140, 140], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (250, 180), (250, 140), (290, 140)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (310, 140), (350, 140), (350, 180)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)

# Left part
ax.plot([250, 150], [280, 280], 'k-', linewidth=4)
ax.plot([110, 110], [320, 340], 'k-', linewidth=4)
ax.plot([250, 150], [380, 380], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (150, 280), (110, 280), (110, 320)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (110, 340), (110, 380), (150, 380)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)

# Right part
ax.plot([350, 450], [280, 280], 'k-', linewidth=4)
ax.plot([490, 490], [320, 340], 'k-', linewidth=4)
ax.plot([350, 450], [380, 380], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (450, 280), (490, 280), (490, 320)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (490, 340), (490, 380), (450, 380)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)

# Bottom part
ax.plot([250, 250], [380, 480], 'k-', linewidth=4)
ax.plot([290, 310], [520, 520], 'k-', linewidth=4)
ax.plot([350, 350], [380, 480], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (250, 480), (250, 520), (290, 520)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)
points = np.array([quadratic_bezier(t, (310, 520), (350, 520), (350, 480)) for t in np.linspace(0, 1, 101)])
ax.plot(points[:, 0], points[:, 1], 'k-', linewidth=4)

# Invert y-axis to match the coordinate system used in the problem statement
plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path

# Define the vertices and codes for the cross
cross_vertices = [(250, 280), 
                  (250, 180), 
                  (250, 140), (290, 140), 
                  (310, 140), 
                  (350, 140), (350, 180),
                  (350, 280), 
                  (450, 280), 
                  (490, 280), (490, 320),
                  (490, 340), 
                  (490, 380), (450, 380),
                  (350, 380), 
                  (350, 480), 
                  (350, 520), (310, 520), 
                  (290, 520), 
                  (250, 520), (250, 480),
                  (250, 380), 
                  (150, 380), 
                  (110, 380), (110, 340), 
                  (110, 320), 
                  (110, 280), (150, 280),
                  (250, 280)]

cross_codes = [path.Path.MOVETO, 
               path.Path.LINETO,
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO, 
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO,
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.LINETO, 
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3,
               path.Path.LINETO, 
               path.Path.CURVE3, path.Path.CURVE3, 
               path.Path.CLOSEPOLY]

# Create the path
cross_path = path.Path(cross_vertices, cross_codes)

# Create the patch
cross_patch = patches.PathPatch(cross_path, facecolor='none', edgecolor='black', lw=2)

# Set up the plot
fig, ax = plt.subplots()
ax.add_patch(cross_patch)
ax.set_xlim(0, 600)
ax.set_ylim(0, 600)

# Invert y-axis to match the coordinate system used in the problem statement
plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %% [markdown]
# **Christmas Tree**

# %%
# Define the vertices and codes for the tree
treeleaf_verts = [(300,100),
(150,100),
(220,250),
(200,250),
(270,400),
(250,400),
(300,550),
(356,408),
(330,400),
(400,250),
(380,250),
(450,106),
(300, 100)]

star_verts = [(300, 550),
(280,570),
(300, 590),
(320,570),
(300, 550)]

treebase_vertices =[(285,100),
(315,100),
(315,70),
(285,70),
(285,100)]

treeleave_code= [path.Path. MOVETO,
path.Path. LINETO, 
path. Path. LINETO, 
path. Path. LINETO, 
path. Path. LINETO, 
path.Path.LINETO, 
path.Path. LINETO, 
path. Path. LINETO, 
path.Path. LINETO, 
path.Path. LINETO, 
path.Path.LINETO, 
path.Path. LINETO, 
path.Path.CLOSEPOLY]

treestar_codes = [path.Path.MOVETO, 
                  path.Path.LINETO,
                  path.Path.LINETO, 
                  path.Path.LINETO, 
                  path.Path.CLOSEPOLY]

treebase_codes = [path.Path.MOVETO, 
                  path.Path.LINETO, 
                  path.Path.LINETO, 
                  path.Path.LINETO, 
                  path.Path.CLOSEPOLY]

# Create the paths
leavespath = path.Path(treeleaf_verts, treeleave_code)
treestarpath = path.Path(star_verts, treestar_codes)
treebasepath = path.Path(treebase_vertices, treebase_codes)

# Create the patches
leavespatch = patches.PathPatch(leavespath, facecolor='green', edgecolor='green', lw=2)
treestarpatch = patches.PathPatch(treestarpath, facecolor='orange', edgecolor='orange', lw=2)
treebasepatch = patches.PathPatch(treebasepath, facecolor='gray', edgecolor='gray', lw=2)

# Set up the plot
fig, ax = plt.subplots()
ax.add_patch(leavespatch)
ax.add_patch(treestarpatch)
ax.add_patch(treebasepatch)
ax.set_xlim(0, 600)
ax.set_ylim(0, 600)
plt.show()
