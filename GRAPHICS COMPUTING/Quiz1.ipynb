# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path
import numpy as np

from PIL import Image, ImageDraw, ImageFont

# %%
image = Image.new("RGB", (800, 800), "white")
draw = ImageDraw.Draw(image)
points = [
    (100, 250),
    (150, 250),
    (150, 200),
    (200, 200),
    (200, 500),
    (400, 500),
    (400, 200),
    (450, 200),
    (450, 250),
    (500, 250),
    (500, 150),
    (450, 100),
    (150, 100),
    (100, 150),
    (100, 250),
]
draw.line(points, fill="blue", width=5)
plt.imshow(image)

# %%
image = Image.new("RGB", (800, 800), "white")
draw = ImageDraw.Draw(image)
points = [
    (100, 350),
    (150, 450),
    (450, 450),
    (500, 350),
    (305, 350),
    (295, 350),  
    (295, 150),
    (305, 150),
    (305, 200),
    (405, 200),
    (305, 150),
    (305, 350),
    (100, 350),
]  
draw.line(points, fill="brown", width=5)
plt.imshow(image)
